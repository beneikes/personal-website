# %% [markdown]
# # FOC: Deadtime in Current Control Loop
#
# Häufigste Struktur: Ein PI-Regler
# Häufigste Entwurfsverfahren: Kompensationsregler.
# Reglerstrecke: Einfacher Fall, korrekte Entkooplung, keien Kreuzidendukivitäten etc. Steady State or exact Compensation no additional Disturbance
#
# $$ u_d = R_s \, i_d + L_d\,\frac{d i_d}{d t} - L_q\,\Omega_{el}\,i_q  $$
#
#  korrekte Entkooplung, keien Kreuzidendukivitäten etc. Steady State or exact Compensation no additional Disturbance. Laplace-Transformation in den Bildbereich
#
# $$ G_p(s) = \frac{1}{L_d\,s+R_s} = \frac{R_s^{-1}}{\frac{L_d}{R_s}\,s+1}$$

# %% [markdown]
# ## Fall 1: Geringe Bandbreite

# %% [markdown]
# $$ k_p = \frac{L_d}{T_i} $$
#
# $$ k_i = \frac{R_s}{T_i} $$
#
# <img src="new.png" alt="alt_text" align="center" width="150" height="150" />
